# %% [markdown]
# Naive Bayes
# 1. Train a naive bayes model on a sentiment analysis task
# 2. Test model
# 3. Compute ratios of positive words to negative words
# 4. Error analysis
# 5. Predict on own tweet

# %%
import pdb
from nltk.corpus import stopwords, twitter_samples
import numpy as np
import pandas as pd
import nltk
import string
from nltk.tokenize import TweetTokenizer
from os import getcwd

# %%
import re
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms
import numpy as np 


def process_tweet(tweet):
    '''
    Input:
        tweet: a string containing a tweet
    Output:
        tweets_clean: a list of words containing the processed tweet

    '''
    stemmer = PorterStemmer()
    stopwords_english = stopwords.words('english')
    # remove stock market tickers like $GE
    tweet = re.sub(r'\$\w*', '', tweet)
    # remove old style retweet text "RT"
    tweet = re.sub(r'^RT[\s]+', '', tweet)
    # remove hyperlinks
    tweet = re.sub(r'https?:\/\/.*[\r\n]*', '', tweet)
    # remove hashtags
    # only removing the hash # sign from the word
    tweet = re.sub(r'#', '', tweet)
    # tokenize tweets
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True,
                               reduce_len=True)
    tweet_tokens = tokenizer.tokenize(tweet)

    tweets_clean = []
    for word in tweet_tokens:
        if (word not in stopwords_english and  # remove stopwords
            word not in string.punctuation):  # remove punctuation
            # tweets_clean.append(word)
            stem_word = stemmer.stem(word)  # stemming word
            tweets_clean.append(stem_word)

    return tweets_clean


def test_lookup(func):
    freqs = {('sad', 0): 4,
             ('happy', 1): 12,
             ('oppressed', 0): 7}
    word = 'happy'
    label = 1
    if func(freqs, word, label) == 12:
        return 'SUCCESS!!'
    return 'Failed Sanity Check!'


def lookup(freqs, word, label):
    '''
    Input:
        freqs: a dictionary with the frequency of each pair (or tuple)
        word: the word to look up
        label: the label corresponding to the word
    Output:
        n: the number of times the word with its corresponding label appears.
    '''
    n = 0  # freqs.get((word, label), 0)

    pair = (word, label)
    if (pair in freqs):
        n = freqs[pair]

    return n

# From: https://matplotlib.org/3.1.1/gallery/statistics/confidence_ellipse.html#sphx-glr-gallery-statistics-confidence-ellipse-py


def confidence_ellipse(x, y, ax, n_std=3.0, facecolor='none', **kwargs):
    """
    Create a plot of the covariance confidence ellipse of `x` and `y`
    Parameters
    ----------
    x, y : array_like, shape (n, )
        Input data.
    ax : matplotlib.axes.Axes
        The axes object to draw the ellipse into.
    n_std : float
        The number of standard deviations to determine the ellipse's radiuses.
    Returns
    -------
    matplotlib.patches.Ellipse
    Other parameters
    ----------------
    kwargs : `~matplotlib.patches.Patch` properties
    """
    if x.size != y.size:
        raise ValueError("x and y must be the same size")

    cov = np.cov(x, y)
    pearson = cov[0, 1] / np.sqrt(cov[0, 0] * cov[1, 1])
    # Using a special case to obtain the eigenvalues of this
    # two-dimensionl dataset.
    ell_radius_x = np.sqrt(1 + pearson)
    ell_radius_y = np.sqrt(1 - pearson)
    ellipse = Ellipse((0, 0),
                      width=ell_radius_x * 2,
                      height=ell_radius_y * 2,
                      facecolor=facecolor,
                      **kwargs)
    scale_x = np.sqrt(cov[0, 0]) * n_std
    mean_x = np.mean(x)

    # calculating the stdandard deviation of y ...
    scale_y = np.sqrt(cov[1, 1]) * n_std
    mean_y = np.mean(y)

    transf = transforms.Affine2D() \
        .rotate_deg(45) \
        .scale(scale_x, scale_y) \
        .translate(mean_x, mean_y)

    ellipse.set_transform(transf + ax.transData)
    return ax.add_patch(ellipse)

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ananya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download('twitter_samples')
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     C:\Users\ananya\AppData\Roaming\nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# True

# %%
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')

# split the data into two pieces, one for training and one for testing (validation set)
test_pos = all_positive_tweets[4000:]
train_pos = all_positive_tweets[:4000]
test_neg = all_negative_tweets[4000:]
train_neg = all_negative_tweets[:4000]

train_x = train_pos + train_neg
test_x = test_pos + test_neg

# avoid assumptions about the length of all_positive_tweets
train_y = np.append(np.ones(len(train_pos)), np.zeros(len(train_neg)))
test_y = np.append(np.ones(len(test_pos)), np.zeros(len(test_neg)))

# %% [markdown]
# Data Processing

# %%
custom_tweet = "RT @Twitter @chapagain Hello There! Have a great day. :) #good #morning http://chapagain.com.np"
print(process_tweet(custom_tweet))
# Out:
# ['hello', 'great', 'day', ':)', 'good', 'morn']

# %%
def count_tweets(result, tweets, ys):
    '''
    Input:
        result: a dictionary that will be used to map each pair to its frequency
        tweets: a list of tweets
        ys: a list corresponding to the sentiment of each tweet (either 0 or 1)
    Output:
        result: a dictionary mapping each pair to its frequency
    '''

    for y, tweet in zip(ys, tweets):
        for word in process_tweet(tweet):
            # define the key, which is the word and label tuple
            pair = (word,y)

            # if the key exists in the dictionary, increment the count
            if pair in result:
                result[pair] += 1

            # else, if the key is new, add it to the dictionary and set the count to 1
            else:
                result[pair] = 1

    return result

# %%
result = {}
tweets = ['i am happy', 'i am tricked', 'i am sad', 'i am tired', 'i am tired']
ys = [1, 0, 0, 0, 0]
count_tweets(result, tweets, ys)
# Out:
# {('happi', 1): 1, ('trick', 0): 1, ('sad', 0): 1, ('tire', 0): 2}

# %% [markdown]
# Model Training
# Advantages:
# 1. Short training time
# 2. Short prediction time
#
# Process of training:
# 1. Identify the number of classes
# 2. Create a probability for each class

# %%
freqs = count_tweets({}, train_x, train_y)

# %%
def train_naive_bayes(freqs, train_x, train_y):
    '''
    Input:
        freqs: dictionary from (word, label) to how often the word appears
        train_x: a list of tweets
        train_y: a list of labels correponding to the tweets (0,1)
    Output:
        logprior: the log prior. (equation 3 above)
        loglikelihood: the log likelihood of you Naive bayes equation. (equation 6 above)
    '''
    loglikelihood = {}
    logprior = 0

    # calculate V, the number of unique words in the vocabulary
    vocab = set([pair[0] for pair in freqs.keys()])
    V = len(vocab)

    # calculate N_pos, N_neg, V_pos, V_neg
    N_pos = N_neg = V_pos = V_neg = 0
    for pair in freqs.keys():
        # if the label is positive (greater than zero)
        if pair[1] > 0:
            # increment the count of unique positive words by 1
            V_pos += 1

            # Increment the number of positive words by the count for this (word, label) pair
            N_pos += freqs[pair]

        # else, the label is negative
        else:
            # increment the count of unique negative words by 1
            V_neg += 1

            # increment the number of negative words by the count for this (word,label) pair
            N_neg += freqs[pair]
        # Calculate D, the number of documents
    D = len(train_y)

    # Calculate D_pos, the number of positive documents
    D_pos = (len(list(filter(lambda x: x > 0, train_y))))

    # Calculate D_neg, the number of negative documents
    D_neg = (len(list(filter(lambda x: x <= 0, train_y))))

    # Calculate logprior
    logprior = np.log(D_pos) - np.log(D_neg)

    # For each word in the vocabulary
    for word in vocab:
        # get the positive and negative frequency of the word
        freq_pos = lookup(freqs,word,1)
        freq_neg = lookup(freqs,word,0)

        # calculate the probability that each word is positive, and negative
        p_w_pos = (freq_pos + 1) / (N_pos + V)
        p_w_neg = (freq_neg + 1) / (N_neg + V)

        # calculate the log likelihood of the word
        loglikelihood[word] = np.log(p_w_pos/p_w_neg)

    return logprior, loglikelihood

# %%
logprior, loglikelihood = train_naive_bayes(freqs, train_x, train_y)
print(logprior)
print(len(loglikelihood))
# Out:
# 0.0
# 9086

# %% [markdown]
# Testing
# Naive Bayes prediction:
# 1. The function takes in the tweet, logprior, loglikelihood.
# 2. It returns the probability that the tweet belongs to the positive or negative class.
# 3. For each tweet, sum up loglikelihoods of each word in the tweet and add the logprior to this sum to get the predicted sentiment of that tweet.

# %%
def naive_bayes_predict(tweet, logprior, loglikelihood):
    '''
    Input:
        tweet: a string
        logprior: a number
        loglikelihood: a dictionary of words mapping to numbers
    Output:
        p: the sum of all the logliklihoods of each word in the tweet (if found in the dictionary) + logprior (a number)

    '''
    # process the tweet to get a list of words
    word_l = process_tweet(tweet)

    # initialize probability to zero
    p = 0

    # add the logprior
    p += logprior

    for word in word_l:

        # check if the word exists in the loglikelihood dictionary
        if word in loglikelihood:
            # add the log likelihood of that word to the probability
            p += loglikelihood[word]

    return p

# %%
my_tweet = 'She frowned.'
p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print('The expected output is', p)
# Out:
# The expected output is 0.0

# %% [markdown]
#  Filter words by Ratio of positive to negative counts

# %%
def get_ratio(freqs, word):
    '''
    Input:
        freqs: dictionary containing the words

    Output: a dictionary with keys 'positive', 'negative', and 'ratio'.
        Example: {'positive': 10, 'negative': 20, 'ratio': 0.5}
    '''
    pos_neg_ratio = {'positive': 0, 'negative': 0, 'ratio': 0.0}
    
    pos_neg_ratio['positive'] = lookup(freqs,word,1)
    pos_neg_ratio['negative'] = lookup(freqs,word,0)

    pos_neg_ratio['ratio'] = (pos_neg_ratio['positive'] + 1)/(pos_neg_ratio['negative'] + 1)
    return pos_neg_ratio

# %%
get_ratio(freqs, 'happi')
# Out:
# {'positive': 161, 'negative': 18, 'ratio': 8.526315789473685}

# %%
def get_words_by_threshold(freqs, label, threshold):
    '''
    Input:
        freqs: dictionary of words
        pos_neg_ratio: dictionary of positive counts, negative counts, and ratio of positive / negative counts.
        label: 1 for positive, 0 for negative
        threshold: ratio that will be used as the cutoff for including a word in the returned dictionary
    Output:
        word_set: dictionary containing the word and information on its positive count, negative count, and ratio of positive to negative counts.
        example of a key value pair:
        {'happi':
            {'positive': 10, 'negative': 20, 'ratio': 0.5}
        }
    '''
    word_list = {}
    for key in freqs.keys():
        word, _ = key
        pos_neg_ratio = get_ratio(freqs, word)

        # if the label is 1 and the ratio is greater than or equal to the threshold...
        if label == 1 and pos_neg_ratio['ratio'] >= threshold :

            # Add the pos_neg_ratio to the dictionary
            word_list[word] = pos_neg_ratio

        # If the label is 0 and the pos_neg_ratio is less than or equal to the threshold...
        elif label == 0 and pos_neg_ratio['ratio'] <= threshold:
            # Add the pos_neg_ratio to the dictionary
            word_list[word] = pos_neg_ratio
    return word_list

# %%
get_words_by_threshold(freqs, label=0, threshold=0.5)
# Out:
# {'pleas': {'positive': 80, 'negative': 243, 'ratio': 0.3319672131147541},
#  'abl': {'positive': 6, 'negative': 17, 'ratio': 0.3888888888888889},
#  'alreadi': {'positive': 19, 'negative': 41, 'ratio': 0.47619047619047616},
#  'age': {'positive': 2, 'negative': 8, 'ratio': 0.3333333333333333},
#  'lunch': {'positive': 3, 'negative': 8, 'ratio': 0.4444444444444444},
#  "i'v": {'positive': 25, 'negative': 64, 'ratio': 0.4},
#  'seen': {'positive': 6, 'negative': 15, 'ratio': 0.4375},
#  'left': {'positive': 10, 'negative': 22, 'ratio': 0.4782608695652174},
#  'kik': {'positive': 16, 'negative': 55, 'ratio': 0.30357142857142855},
#  'kikm': {'positive': 1, 'negative': 7, 'ratio': 0.25},
#  'hous': {'positive': 5, 'negative': 12, 'ratio': 0.46153846153846156},
#  'feel': {'positive': 33, 'negative': 131, 'ratio': 0.25757575757575757},
#  'wish': {'positive': 29, 'negative': 63, 'ratio': 0.46875},
#  'im': {'positive': 38, 'negative': 108, 'ratio': 0.3577981651376147},
#  'asleep': {'positive': 7, 'negative': 17, 'ratio': 0.4444444444444444},
#  'green': {'positive': 2, 'negative': 7, 'ratio': 0.375},
#  'babi': {'positive': 17, 'negative': 37, 'ratio': 0.47368421052631576},
#  "can't": {'positive': 31, 'negative': 148, 'ratio': 0.21476510067114093},
#  'yet': {'positive': 12, 'negative': 29, 'ratio': 0.43333333333333335},
#  'still': {'positive': 37, 'negative': 104, 'ratio': 0.3619047619047619},
#  'drain': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'fuck': {'positive': 20, 'negative': 47, 'ratio': 0.4375},
#  'nude': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'sleep': {'positive': 35, 'negative': 71, 'ratio': 0.5},
#  'want': {'positive': 69, 'negative': 185, 'ratio': 0.3763440860215054},
#  'stage': {'positive': 2, 'negative': 12, 'ratio': 0.23076923076923078},
#  'miss': {'positive': 17, 'negative': 239, 'ratio': 0.075},
#  'chanc': {'positive': 3, 'negative': 14, 'ratio': 0.26666666666666666},
#  'ice': {'positive': 6, 'negative': 29, 'ratio': 0.23333333333333334},
#  'cream': {'positive': 6, 'negative': 27, 'ratio': 0.25},
#  'home': {'positive': 20, 'negative': 52, 'ratio': 0.39622641509433965},
#  'small': {'positive': 1, 'negative': 8, 'ratio': 0.2222222222222222},
#  'could': {'positive': 25, 'negative': 51, 'ratio': 0.5},
#  'yesterday': {'positive': 4, 'negative': 9, 'ratio': 0.5},
#  'clean': {'positive': 1, 'negative': 6, 'ratio': 0.2857142857142857},
#  'wanna': {'positive': 23, 'negative': 76, 'ratio': 0.3116883116883117},
#  'leav': {'positive': 11, 'negative': 31, 'ratio': 0.375},
#  'without': {'positive': 9, 'negative': 20, 'ratio': 0.47619047619047616},
#  'delay': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'pain': {'positive': 8, 'negative': 17, 'ratio': 0.5},
#  'went': {'positive': 10, 'negative': 27, 'ratio': 0.39285714285714285},
#  'rip': {'positive': 3, 'negative': 8, 'ratio': 0.4444444444444444},
#  'gonna': {'positive': 16, 'negative': 44, 'ratio': 0.37777777777777777},
#  'end': {'positive': 13, 'negative': 36, 'ratio': 0.3783783783783784},
#  'bite': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'derek': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'traffic': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'stress': {'positive': 4, 'negative': 9, 'ratio': 0.5},
#  'omg': {'positive': 13, 'negative': 48, 'ratio': 0.2857142857142857},
#  'find': {'positive': 20, 'negative': 45, 'ratio': 0.45652173913043476},
#  'hard': {'positive': 9, 'negative': 30, 'ratio': 0.3225806451612903},
#  'hair': {'positive': 7, 'negative': 16, 'ratio': 0.47058823529411764},
#  'tbh': {'positive': 5, 'negative': 12, 'ratio': 0.46153846153846156},
#  'onlin': {'positive': 4, 'negative': 13, 'ratio': 0.35714285714285715},
#  'town': {'positive': 3, 'negative': 11, 'ratio': 0.3333333333333333},
#  'terribl': {'positive': 2, 'negative': 10, 'ratio': 0.2727272727272727},
#  'snapchat': {'positive': 31, 'negative': 64, 'ratio': 0.49230769230769234},
#  'kikmenow': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'snapm': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'amazon': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'kikmeguy': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'sinc': {'positive': 11, 'negative': 33, 'ratio': 0.35294117647058826},
#  'though': {'positive': 16, 'negative': 44, 'ratio': 0.37777777777777777},
#  '24': {'positive': 3, 'negative': 9, 'ratio': 0.4},
#  'spam': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'claim': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'hurt': {'positive': 4, 'negative': 33, 'ratio': 0.14705882352941177},
#  'bad': {'positive': 14, 'negative': 54, 'ratio': 0.2727272727272727},
#  'fat': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'co': {'positive': 1, 'negative': 6, 'ratio': 0.2857142857142857},
#  'ate': {'positive': 4, 'negative': 10, 'ratio': 0.45454545454545453},
#  'liter': {'positive': 5, 'negative': 13, 'ratio': 0.42857142857142855},
#  'sigh': {'positive': 3, 'negative': 12, 'ratio': 0.3076923076923077},
#  'happen': {'positive': 13, 'negative': 43, 'ratio': 0.3181818181818182},
#  'internet': {'positive': 2, 'negative': 7, 'ratio': 0.375},
#  'school': {'positive': 9, 'negative': 22, 'ratio': 0.43478260869565216},
#  'wrong': {'positive': 9, 'negative': 27, 'ratio': 0.35714285714285715},
#  'aww': {'positive': 8, 'negative': 18, 'ratio': 0.47368421052631576},
#  'hate': {'positive': 9, 'negative': 45, 'ratio': 0.21739130434782608},
#  'cant': {'positive': 13, 'negative': 41, 'ratio': 0.3333333333333333},
#  'decid': {'positive': 2, 'negative': 9, 'ratio': 0.3},
#  'heart': {'positive': 6, 'negative': 22, 'ratio': 0.30434782608695654},
#  'sorri': {'positive': 13, 'negative': 117, 'ratio': 0.11864406779661017},
#  'came': {'positive': 7, 'negative': 16, 'ratio': 0.47058823529411764},
#  '1/2': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'spend': {'positive': 1, 'negative': 6, 'ratio': 0.2857142857142857},
#  'marathon': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'cri': {'positive': 7, 'negative': 38, 'ratio': 0.20512820512820512},
#  'ahhh': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'mental': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'fever': {'positive': 1, 'negative': 6, 'ratio': 0.2857142857142857},
#  'room': {'positive': 4, 'negative': 9, 'ratio': 0.5},
#  'car': {'positive': 5, 'negative': 11, 'ratio': 0.5},
#  'gone': {'positive': 4, 'negative': 16, 'ratio': 0.29411764705882354},
#  'worst': {'positive': 3, 'negative': 10, 'ratio': 0.36363636363636365},
#  'due': {'positive': 2, 'negative': 12, 'ratio': 0.23076923076923078},
#  'rn': {'positive': 4, 'negative': 13, 'ratio': 0.35714285714285715},
#  'wtf': {'positive': 2, 'negative': 11, 'ratio': 0.25},
#  "there'": {'positive': 6, 'negative': 13, 'ratio': 0.5},
#  'middl': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'babe': {'positive': 7, 'negative': 16, 'ratio': 0.47058823529411764},
#  'e': {'positive': 3, 'negative': 9, 'ratio': 0.4},
#  'massiv': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'tire': {'positive': 5, 'negative': 37, 'ratio': 0.15789473684210525},
#  'album': {'positive': 5, 'negative': 11, 'ratio': 0.5},
#  '1st': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'apart': {'positive': 2, 'negative': 7, 'ratio': 0.375},
#  'kill': {'positive': 3, 'negative': 13, 'ratio': 0.2857142857142857},
#  'sadli': {'positive': 1, 'negative': 10, 'ratio': 0.18181818181818182},
#  'sad': {'positive': 5, 'negative': 100, 'ratio': 0.0594059405940594},
#  'emot': {'positive': 2, 'negative': 7, 'ratio': 0.375},
#  'reach': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'dont': {'positive': 11, 'negative': 39, 'ratio': 0.3},
#  'broken': {'positive': 3, 'negative': 8, 'ratio': 0.4444444444444444},
#  'mad': {'positive': 3, 'negative': 8, 'ratio': 0.4444444444444444},
#  'wast': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'tho': {'positive': 10, 'negative': 24, 'ratio': 0.44},
#  'outsid': {'positive': 3, 'negative': 8, 'ratio': 0.4444444444444444},
#  'otp': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'report': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'cat': {'positive': 5, 'negative': 12, 'ratio': 0.46153846153846156},
#  'ugh': {'positive': 1, 'negative': 23, 'ratio': 0.08333333333333333},
#  'leed': {'positive': 1, 'negative': 9, 'ratio': 0.2},
#  'pa': {'positive': 1, 'negative': 8, 'ratio': 0.2222222222222222},
#  '7': {'positive': 4, 'negative': 13, 'ratio': 0.35714285714285715},
#  'mum': {'positive': 2, 'negative': 12, 'ratio': 0.23076923076923078},
#  'danc': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'pl': {'positive': 6, 'negative': 24, 'ratio': 0.28},
#  'voic': {'positive': 3, 'negative': 8, 'ratio': 0.4444444444444444},
#  'physic': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'stop': {'positive': 14, 'negative': 35, 'ratio': 0.4166666666666667},
#  'choos': {'positive': 2, 'negative': 7, 'ratio': 0.375},
#  'sell': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'assign': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'ohh': {'positive': 2, 'negative': 8, 'ratio': 0.3333333333333333},
#  'ko': {'positive': 3, 'negative': 8, 'ratio': 0.4444444444444444},
#  '</3': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  '(:': {'positive': 1, 'negative': 6, 'ratio': 0.2857142857142857},
#  'sick': {'positive': 1, 'negative': 32, 'ratio': 0.06060606060606061},
#  'goodby': {'positive': 5, 'negative': 12, 'ratio': 0.46153846153846156},
#  'bitch': {'positive': 3, 'negative': 8, 'ratio': 0.4444444444444444},
#  'bought': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'fast': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'ang': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'harri': {'positive': 2, 'negative': 8, 'ratio': 0.3333333333333333},
#  'bc': {'positive': 7, 'negative': 39, 'ratio': 0.2},
#  'woke': {'positive': 3, 'negative': 13, 'ratio': 0.2857142857142857},
#  'hang': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'weather': {'positive': 7, 'negative': 25, 'ratio': 0.3076923076923077},
#  'cast': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'wednesday': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'earlier': {'positive': 3, 'negative': 8, 'ratio': 0.4444444444444444},
#  '😭': {'positive': 2, 'negative': 22, 'ratio': 0.13043478260869565},
#  'except': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'shit': {'positive': 11, 'negative': 26, 'ratio': 0.4444444444444444},
#  'madrid': {'positive': 2, 'negative': 7, 'ratio': 0.375},
#  'certain': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'forgot': {'positive': 2, 'negative': 12, 'ratio': 0.23076923076923078},
#  'sale': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'disappoint': {'positive': 1, 'negative': 11, 'ratio': 0.16666666666666666},
#  'paper': {'positive': 3, 'negative': 12, 'ratio': 0.3076923076923077},
#  'lose': {'positive': 2, 'negative': 7, 'ratio': 0.375},
#  'suck': {'positive': 8, 'negative': 20, 'ratio': 0.42857142857142855},
#  'ahead': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'tear': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'eat': {'positive': 4, 'negative': 23, 'ratio': 0.20833333333333334},
#  'youuu': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  '”': {'positive': 5, 'negative': 11, 'ratio': 0.5},
#  'bank': {'positive': 1, 'negative': 8, 'ratio': 0.2222222222222222},
#  'wet': {'positive': 2, 'negative': 10, 'ratio': 0.2727272727272727},
#  'bt': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'weird': {'positive': 4, 'negative': 9, 'ratio': 0.5},
#  'poor': {'positive': 3, 'negative': 24, 'ratio': 0.16},
#  'brother': {'positive': 3, 'negative': 9, 'ratio': 0.4},
#  'rate': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'mean': {'positive': 19, 'negative': 39, 'ratio': 0.5},
#  'ago': {'positive': 8, 'negative': 18, 'ratio': 0.47368421052631576},
#  'slow': {'positive': 2, 'negative': 8, 'ratio': 0.3333333333333333},
#  'mouth': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'outfit': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'announc': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'seat': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'london': {'positive': 4, 'negative': 10, 'ratio': 0.45454545454545453},
#  'driver': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'cut': {'positive': 2, 'negative': 13, 'ratio': 0.21428571428571427},
#  'famou': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'snake': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'perform': {'positive': 2, 'negative': 7, 'ratio': 0.375},
#  'return': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'teeth': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'activ': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'box': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'na': {'positive': 6, 'negative': 20, 'ratio': 0.3333333333333333},
#  'fell': {'positive': 2, 'negative': 8, 'ratio': 0.3333333333333333},
#  'fall': {'positive': 5, 'negative': 13, 'ratio': 0.42857142857142855},
#  'everyday': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'advanc': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'switch': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'class': {'positive': 1, 'negative': 8, 'ratio': 0.2222222222222222},
#  'what': {'positive': 3, 'negative': 7, 'ratio': 0.5},
#  'goat': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'wat': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'realis': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'anymor': {'positive': 3, 'negative': 17, 'ratio': 0.2222222222222222},
#  '�': {'positive': 2, 'negative': 21, 'ratio': 0.13636363636363635},
#  'hahahaha': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'money': {'positive': 5, 'negative': 20, 'ratio': 0.2857142857142857},
#  'wifi': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'crap': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'hand': {'positive': 4, 'negative': 11, 'ratio': 0.4166666666666667},
#  'manag': {'positive': 5, 'negative': 12, 'ratio': 0.46153846153846156},
#  'nobodi': {'positive': 2, 'negative': 9, 'ratio': 0.3},
#  'climb': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'cuddl': {'positive': 1, 'negative': 6, 'ratio': 0.2857142857142857},
#  'lie': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'black': {'positive': 4, 'negative': 10, 'ratio': 0.45454545454545453},
#  '9': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'bore': {'positive': 6, 'negative': 15, 'ratio': 0.4375},
#  'tmr': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'pizza': {'positive': 1, 'negative': 7, 'ratio': 0.25},
#  'everybodi': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'acc': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'til': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'shade': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'grey': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'told': {'positive': 4, 'negative': 9, 'ratio': 0.5},
#  'hella': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'hell': {'positive': 3, 'negative': 10, 'ratio': 0.36363636363636365},
#  'park': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'fri': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'flight': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'kikchat': {'positive': 1, 'negative': 9, 'ratio': 0.2},
#  'kikgirl': {'positive': 4, 'negative': 12, 'ratio': 0.38461538461538464},
#  'jk': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'vidcon': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'white': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'huhu': {'positive': 3, 'negative': 14, 'ratio': 0.26666666666666666},
#  'english': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'wont': {'positive': 3, 'negative': 8, 'ratio': 0.4444444444444444},
#  'hungri': {'positive': 2, 'negative': 13, 'ratio': 0.21428571428571427},
#  'kit': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'block': {'positive': 2, 'negative': 9, 'ratio': 0.3},
#  'damn': {'positive': 3, 'negative': 22, 'ratio': 0.17391304347826086},
#  'colleg': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'huh': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'annoy': {'positive': 2, 'negative': 8, 'ratio': 0.3333333333333333},
#  'sing': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'lmao': {'positive': 2, 'negative': 10, 'ratio': 0.2727272727272727},
#  'repli': {'positive': 5, 'negative': 12, 'ratio': 0.46153846153846156},
#  'rude': {'positive': 3, 'negative': 8, 'ratio': 0.4444444444444444},
#  'nh': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'seriou': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'flip': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'session': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'comic': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'none': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'gross': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'stuck': {'positive': 3, 'negative': 8, 'ratio': 0.4444444444444444},
#  'upset': {'positive': 1, 'negative': 10, 'ratio': 0.18181818181818182},
#  'cloth': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  '50': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'airport': {'positive': 2, 'negative': 7, 'ratio': 0.375},
#  'load': {'positive': 1, 'negative': 8, 'ratio': 0.2222222222222222},
#  '1d': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'sc': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  ':(': {'positive': 1, 'negative': 3663, 'ratio': 0.0005458515283842794},
#  'server': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'quiet': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  '5am': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'zayn': {'positive': 2, 'negative': 8, 'ratio': 0.3333333333333333},
#  'deal': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'unfortun': {'positive': 2, 'negative': 14, 'ratio': 0.2},
#  'eid': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'data': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'face': {'positive': 6, 'negative': 17, 'ratio': 0.3888888888888889},
#  'srsli': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'infinit': {'positive': 2, 'negative': 10, 'ratio': 0.2727272727272727},
#  'cold': {'positive': 1, 'negative': 13, 'ratio': 0.14285714285714285},
#  'shock': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'anxieti': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'spain': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'def': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'x15': {'positive': 1, 'negative': 35, 'ratio': 0.05555555555555555},
#  'aw': {'positive': 2, 'negative': 30, 'ratio': 0.0967741935483871},
#  'entir': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'sm': {'positive': 1, 'negative': 6, 'ratio': 0.2857142857142857},
#  'screw': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'amber': {'positive': 2, 'negative': 8, 'ratio': 0.3333333333333333},
#  'au': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'women': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'joke': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'shame': {'positive': 1, 'negative': 19, 'ratio': 0.1},
#  'winter': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'pm': {'positive': 2, 'negative': 8, 'ratio': 0.3333333333333333},
#  'longer': {'positive': 1, 'negative': 9, 'ratio': 0.2},
#  'countrymus': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'languag': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'confus': {'positive': 2, 'negative': 7, 'ratio': 0.375},
#  'common': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'cc': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'lion': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'ppl': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'wing': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'whilst': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'indiemus': {'positive': 3, 'negative': 10, 'ratio': 0.36363636363636365},
#  'dat': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'mistak': {'positive': 2, 'negative': 6, 'ratio': 0.42857142857142855},
#  'nake': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'heck': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'starbuck': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'everywher': {'positive': 1, 'negative': 6, 'ratio': 0.2857142857142857},
#  'ran': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'broadcast': {'positive': 1, 'negative': 6, 'ratio': 0.2857142857142857},
#  'score': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'kikhorni': {'positive': 1, 'negative': 10, 'ratio': 0.18181818181818182},
#  'interraci': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'makeup': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'mommi': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'level': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'hornykik': {'positive': 2, 'negative': 14, 'ratio': 0.2},
#  'didnt': {'positive': 1, 'negative': 19, 'ratio': 0.1},
#  'shirt': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'gig': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'payment': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'shave': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  '😒': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'worker': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'tax': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'crave': {'positive': 1, 'negative': 7, 'ratio': 0.25},
#  'ignor': {'positive': 1, 'negative': 15, 'ratio': 0.125},
#  "where'": {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'space': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'wors': {'positive': 1, 'negative': 7, 'ratio': 0.25},
#  'ding': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'pak': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'dylan': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'tl': {'positive': 1, 'negative': 7, 'ratio': 0.25},
#  'hack': {'positive': 1, 'negative': 7, 'ratio': 0.25},
#  'scare': {'positive': 1, 'negative': 13, 'ratio': 0.14285714285714285},
#  'tryna': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'horribl': {'positive': 1, 'negative': 8, 'ratio': 0.2222222222222222},
#  'scari': {'positive': 1, 'negative': 6, 'ratio': 0.2857142857142857},
#  'bestoftheday': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'oralsex': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'broke': {'positive': 1, 'negative': 6, 'ratio': 0.2857142857142857},
#  'ass': {'positive': 1, 'negative': 8, 'ratio': 0.2222222222222222},
#  'banana': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'aint': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'massag': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'isnt': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'taken': {'positive': 1, 'negative': 7, 'ratio': 0.25},
#  'mpoint': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'hopeless': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'ikea': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'slide': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'bani': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'neighbour': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'motor': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'search': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'sialan': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'athabasca': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'glacier': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  '1948': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  ':-(': {'positive': 0, 'negative': 378, 'ratio': 0.002638522427440633},
#  'jasper': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'jaspernationalpark': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'alberta': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'explorealberta': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'mare': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'ivan': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'hahahah': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'replac': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'bi-polar': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'grasp': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'digit': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'lone': {'positive': 0, 'negative': 7, 'ratio': 0.125},
#  '😩': {'positive': 0, 'negative': 11, 'ratio': 0.08333333333333333},
#  'choreograph': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'mingm': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'truli': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'pee': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'newwin': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'doushit': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'gundam': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'dollar': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'pale': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'imit': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'rash': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'absent': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'sequel': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'ouucchhh': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'wisdom': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'frighten': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'pret': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'wkwkw': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'verfi': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'sentir-s': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'incompleta': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'thwart': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'zant': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  "when'": {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'audraesar': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'craaazzyy': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'helium': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'climatechang': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  "california'": {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'influenti': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'pollut': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'watchdog': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'califor': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'elhaida': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'juri': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  '10th': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'televot': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'idaho': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'drought-link': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'die-of': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'abrupt': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'climat': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'mammoth': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'megafauna': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  "australia'": {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'dirtiest': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'energi': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'biomass': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'golf': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'ulti': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'prexi': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'kindergarten': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'sane': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'boss': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'hozier': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'soooner': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'respectlost': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'hypercholesteloremia': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'calibraska': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'genuin': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'contend': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'older': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'ao': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'yun': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'encor': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  '4thwin': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'baymax': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'mixer': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'wft': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'hub': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'loud': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'parasyt': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'alll': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'zayniscomingbackonjuli': {'positive': 0, 'negative': 19, 'ratio': 0.05},
#  '26': {'positive': 0, 'negative': 20, 'ratio': 0.047619047619047616},
#  'era': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  '。': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'ω': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  '」': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  '∠': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'nathann': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'dieididieieiei': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'netflix': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'ervin': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'desper': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'amargolonnard': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'batalladelosgallo': {'positive': 0,
#   'negative': 2,
#   'ratio': 0.3333333333333333},
#  'webcamsex': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'duti': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  "u'v": {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'alien': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'sorka': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'funer': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'nonexist': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'wowza': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'fah': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'boo': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'hyung': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'predict': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'sj': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'nomin': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'brace': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'omggg': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'whyyi': {'positive': 0, 'negative': 6, 'ratio': 0.14285714285714285},
#  'evan': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'opt': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'muster': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'merch': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'savanna': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'straw': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'yester': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'when': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'consum': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'werk': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'foreal': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'wesen': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'uwes': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'bosen': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'egg': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'benni': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'badli': {'positive': 0, 'negative': 9, 'ratio': 0.1},
#  '>:(': {'positive': 0, 'negative': 43, 'ratio': 0.022727272727272728},
#  'zaz': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'rehash': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'mushroom': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'piec': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'vicki': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  '45': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'hahah': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'ninasti': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'tsktsk': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'dick': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'kawaii': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'manli': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'youu': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'potato': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'asf': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'eish': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'ive': {'positive': 0, 'negative': 10, 'ratio': 0.09090909090909091},
#  'lost': {'positive': 0, 'negative': 19, 'ratio': 0.05},
#  'mojo': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'mara': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'neh': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'councillor': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'sholong': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'reject': {'positive': 0, 'negative': 6, 'ratio': 0.14285714285714285},
#  'gee': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'gidi': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'lago': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'ehn': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'arrest': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'idk': {'positive': 0, 'negative': 17, 'ratio': 0.05555555555555555},
#  'anybodi': {'positive': 0, 'negative': 7, 'ratio': 0.125},
#  'disappear': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'daze': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'fragment': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  "would'v": {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'walao': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'djderek': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'legend': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'tragedi': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  '💪🏻': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  '🐒': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'struck': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'belgium': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'fabian': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'delph': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'fallen': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'drake': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'silent': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'mumma': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'pray': {'positive': 0, 'negative': 12, 'ratio': 0.07692307692307693},
#  'appropri': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'across': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'hindi': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  '5s': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'disabl': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'pension': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'ptsd': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'imposs': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'financi': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'nooo': {'positive': 0, 'negative': 10, 'ratio': 0.09090909090909091},
#  'toghet': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  '21st': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'snsd': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'anna': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'akana': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'askip': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  "t'exist": {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'kei': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'kate': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'spade': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'pero': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'walang': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'agesss': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'corinehurleigh': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'snapchatm': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'zara': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'trouser': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  "it'okay": {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'freed': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'orcalov': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'lew': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'crumbl': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'mcflurri': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'cabl': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  "venus'": {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'concept': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'rli': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'tagal': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'appoint': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'cereal': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'previou': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  '73': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'fansign': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'expens': {'positive': 0, 'negative': 7, 'ratio': 0.125},
#  'zzzz': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  "bff'": {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  "deosn't": {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'liverpool': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'lowest': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'tacki': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'haaretz': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'israel': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'syria': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'chemic': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'wsj': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'rep': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'wong': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'confisc': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'icepack': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'dose': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'whimper': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'senpai': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'buttsex': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  "dn't": {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'brk': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  ":'(": {'positive': 0, 'negative': 12, 'ratio': 0.07692307692307693},
#  'falsetto': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'zone': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'loveofmylif': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  's2': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'untruth': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'ij': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  '💥': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  '💫': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'soshi': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'buttt': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'heyyy': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'yeol': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'dancee': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'nemanja': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'vidic': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'roma': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  "mom'": {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'linguist': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  "dad'": {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'dumbest': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'crash': {'positive': 0, 'negative': 6, 'ratio': 0.14285714285714285},
#  'resourc': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'vehicl': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'ayex': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'lamon': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'scroll': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'curv': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'cement': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  '10.3': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'jmu': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'camp': {'positive': 0, 'negative': 7, 'ratio': 0.125},
#  'teas': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'awuna': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'mbulelo': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'although': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'plug': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'fuse': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'dammit': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'carlton': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'aflblueshawk': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  "alex'": {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'motorsport': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'cheeki': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'seo': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'nl': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'christi': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'niec': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'bloodi': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'sandwhich': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'buset': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'discrimin': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'pregnanc': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'foot': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'f': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'matern': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'kick': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'domesticviol': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'domest': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'violenc': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'victim': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  '98fm': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'govern': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'sapiosexu': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'beta': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'hogan': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'scrub': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'wwe': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'iren': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'naa': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'sold': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'h_my_k': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'valentin': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'et': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  "r'ship": {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'btwn': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'homo': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'biphob': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'disciplin': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'incl': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'european': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'lang': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'fresherstofin': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  '💔': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'realist': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'benzema': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'hahahahahaah': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'donno': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'russian': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'waaa': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'eidwithgrof': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'boreddd': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'mug': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'tiddler': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  '에이핑크': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  '더쇼': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'clan': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'slot': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'pfff': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'bugbounti': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'self-xss': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'header': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'poison': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'execut': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'ktksbye': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'cancel': {'positive': 0, 'negative': 10, 'ratio': 0.09090909090909091},
#  'petit': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  '600': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'odoo': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'partner': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'effin': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'ap': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'elsewher': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'branch': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'pod': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'd;': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'talk-kama': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'hawako': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'waa': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'kimaaani': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'prisss': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'baggag': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'sugar': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'agh': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'undercoverboss': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'تكفى': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'ach': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'wrist': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'ligo': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'dozen': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'shark': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'heartach': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'zayniscomingback': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'sweden': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'elmhurst': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'etid': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  "chillin'with": {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'father': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'istanya': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  '2suppli': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'infrastructur': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'nurs': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'paramed': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'countless': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  '2cope': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'plea': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'arian': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'kendal': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'kyli': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  "kylie'": {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'manila': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'jeebu': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'reabsorbt': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'abscess': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'crown': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'ooouch': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'barney': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  "be'": {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'problemat': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'mess': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'maa': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'bangalor': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'lui': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'manzano': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'shaaa': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'conven': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  '2:30': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'delet': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'airfield': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'jet': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  "jack'": {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  "mommy'": {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'overweight': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'sigeg': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'habhab': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'masud': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'kaha': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'akong': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'pala': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'dolphin': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'holi': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'anythin': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'bewar': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'agonis': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'modimo': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'tseba': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'wena': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'fela': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'nowt': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'willi': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'gon': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'vomit': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'bowl': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'devast': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'titan': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'ae': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'shini': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'wavi': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'emo': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'germani': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'shed': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'bheyp': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'ayemso': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'swell': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'wut': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'viciou': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'simpson': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'singapor': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'pooo': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'bh3': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'pitchwar': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'chap': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  "mine'": {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'transcript': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  "apma'": {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'timw': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'vitamin': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'healthier': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'stretch': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'blockjam': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  "schedule'": {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'whack': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'thelock': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  '76': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'hotgirl': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'ghantay': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'nai': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'hay': {'positive': 0, 'negative': 7, 'ratio': 0.125},
#  'deni': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'laguna': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'exit': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'gomen': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'grew': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'inch': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'suuuper': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  '65': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'inact': {'positive': 0, 'negative': 6, 'ratio': 0.14285714285714285},
#  'orphan': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'whaaat': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'kaya': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'naaan': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'paus': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  '3:30': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'inglewood': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'ummm': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'charcoal': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'mid-end': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'noooo': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'rodfanta': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'wasp': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'sting': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'avert': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'exo': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'seekli': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'riptito': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'manbearpig': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'academ': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'exclus': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'unfair': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'esp': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'bleak': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'german': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'chart': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'pfft': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'polaroid': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'newbethvideo': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'greec': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'xur': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'imi': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'stud': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'hund': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  '3.4': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'yach': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'huvvft': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'zoo': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'fieldtrip': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'sizw': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'boredom': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'who': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'sins': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'somehow': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'tini': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'barbel': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'ps': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'looong': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'litro': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'shepherd': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'lami': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'lungomar': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'pesaro': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'giachietittiwed': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'igersoftheday': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'summertim': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'nose': {'positive': 0, 'negative': 6, 'ratio': 0.14285714285714285},
#  'scarf': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'afford': {'positive': 0, 'negative': 7, 'ratio': 0.125},
#  'woe': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'nigga': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'motn': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'make-up': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'ver': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'huhuhu': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  "m'ladi": {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'j8': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'j11': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'm20': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'acad': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'schedul': {'positive': 0, 'negative': 7, 'ratio': 0.125},
#  'nowww': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'hugh': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'paw': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'muddi': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'heyi': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'cupcak': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'talaga': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'poppin': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'joc': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'playin': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'subj': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'sobrang': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'bv': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'zamn': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'afropunk': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'fest': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'shithous': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'ladder': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'wrack': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'booset': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'restart': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'assassin': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'creed': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'ii': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'heap': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'ankl': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'puddl': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'slipper': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'eve': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'sararoc': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'anywayhedidanicejob': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  '😞': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'local': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'cruis': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'wail': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'wheelchair': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  '26week': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'sbenu': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'sasin': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'anarchi': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'candl': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'forehead': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'medicin': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'hoya': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'mah': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'a': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'hush': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'gurli': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'purti': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'closer': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'shiver': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'paid': {'positive': 0, 'negative': 8, 'ratio': 0.1111111111111111},
#  'properli': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'gol': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'pea': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'tierd': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  "eye'": {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'thnkyouuu': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'highlight': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'courag': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'fishi': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'idek': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'apink': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'bulet': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'gendut': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'noo': {'positive': 0, 'negative': 3, 'ratio': 0.25},
#  'hotwheel': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'ms': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'patch': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'ahaha': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'akon': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'nightmar': {'positive': 0, 'negative': 7, 'ratio': 0.125},
#  'mino': {'positive': 0, 'negative': 2, 'ratio': 0.3333333333333333},
#  'crazyyi': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'thooo': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'zz': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  'straight': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'soundcheck': {'positive': 0, 'negative': 1, 'ratio': 0.5},
#  ...}

# %% [markdown]
# Error Analysis

# %%
print('Truth Predicted Tweet')
for x, y in zip(test_x, test_y):
    y_hat = naive_bayes_predict(x, logprior, loglikelihood)
    if y != (np.sign(y_hat) > 0):
        print('%d\t%0.2f\t%s' % (y, np.sign(y_hat) > 0, ' '.join(
            process_tweet(x)).encode('ascii', 'ignore')))
# Out:
# Truth Predicted Tweet
# 1	0.00	b''
# 1	0.00	b'truli later move know queen bee upward bound movingonup'
# 1	0.00	b'new report talk burn calori cold work harder warm feel better weather :p'
# 1	0.00	b'harri niall 94 harri born ik stupid wanna chang :d'
# 1	0.00	b''
# 1	0.00	b''
# 1	0.00	b'park get sunlight'
# 1	0.00	b'uff itna miss karhi thi ap :p'
# 0	1.00	b'hello info possibl interest jonatha close join beti :( great'
# 0	1.00	b'u prob fun david'
# 0	1.00	b'pat jay'
# 0	1.00	b'whatev stil l young >:-('

# %%
my_tweet = 'It is exciting how much you can learn about NLP'

p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print(p)
# Out:
# 1.8746066407350215
